# %% [markdown]
# # AAI614: Data Science & its Applications
#
# *Notebook 2.4: Exploratory Data Analysis*
#
# <a href="https://colab.research.google.com/github/gassaf2/AAI614_assaf/blob/main/week2/Notebook2.4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import subprocess
import pkg_resources

required = {'autoviz'}
installed = {pkg.key for pkg in pkg_resources.working_set}
missing = required - installed

if missing:
    python = sys.executable
    subprocess.check_call([python, '-m', 'pip', 'install', *missing], stdout=subprocess.DEVNULL)
    
import pandas as pd
import numpy as np
from autoviz import AutoViz_Class
import ssl

ssl._create_default_https_context = ssl._create_unverified_context
# Out:
# Imported v0.1.905. Please call AutoViz in this sequence:
#     AV = AutoViz_Class()
#     %matplotlib inline
#     dfte = AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=1, lowess=False,
#                chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30, save_plot_dir=None)

# %%
students = pd.read_csv("https://raw.githubusercontent.com/harmanani/AAI614/main/Week%202/students.csv")

# %% [markdown]
# ##### If you don’t have a target variable you can leave it blank:

# %%
target_variable = 'Avg_Hours_Studied_per_week'

# %%
AV = AutoViz_Class()
sep = ','


dft = AV.AutoViz(students, sep, depVar=target_variable, dfte="",
           header=0, verbose=1,
            lowess=False,chart_format='bokeh',max_rows_analyzed=500,max_cols_analyzed=30)
# Out:
# Shape of your Data Set loaded: (9, 6)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  2
#     Number of Integer-Categorical Columns =  0
#     Number of String-Categorical Columns =  2
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  1
#     Number of Columns to Delete =  0
#     5 Predictors classified...
#         1 variable(s) removed since they were ID or low-information variables
#         List of variables removed: ['Student Name']
#
# ...

# %% [markdown]
# # Converting the salary to numbers after replaving the $ and k with an empty string and then converting it to float

# %%
students.head()
# Remove the dollar sign and 'k', then convert to integers
students['Salary'] = students['Salary'].replace('[\$,k]', '', regex=True).astype(float)*1000
students = students.dropna(subset=['GPA'])
students = students.dropna(subset=['Avg_Hours_Studied_per_week'])
students = students.dropna(subset=['Sense of Humour (0-5)'])
students.head()
# Out:
#   Student Name  Avg_Hours_Studied_per_week  GPA   University   \
# 1      Jerry                 35             3.5      Columbia
# 2     Elaine                 55             4.0      Columbia
# 3      Cosmo                  5             2.0  City College
# 4     Newman                 25             2.8  City College
# 6    Estelle                100             3.2  Festivus Uni
#
#    Sense of Humour (0-5)  Salary
# 1           5.0           80000.0
# 2           4.2           60000.0
# 3           2.0           25000.0
# 4           0.0           50000.0
# 6           1.7               0.0

# %%
target_variable = 'Avg_Hours_Studied_per_week'

# %%
AV = AutoViz_Class()
sep = ','


dft = AV.AutoViz(students, sep, depVar=target_variable, dfte="",
           header=0, verbose=1,
            lowess=False,chart_format='bokeh',max_rows_analyzed=500,max_cols_analyzed=30)
# Out:
# Shape of your Data Set loaded: (6, 6)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  3
#     Number of Integer-Categorical Columns =  0
#     Number of String-Categorical Columns =  1
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  1
#     Number of Columns to Delete =  0
#     5 Predictors classified...
#         1 variable(s) removed since they were ID or low-information variables
#         List of variables removed: ['Student Name']
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

students_numeric = students.select_dtypes(include='number')


correlation_matrix = students_numeric.corr()


#plt.figure(figsize=(10, 8))

# Create a heatmap of the correlation matrix
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)


plt.show()

# %%
target_variable = 'Salary'
AV = AutoViz_Class()
sep = ','


dft = AV.AutoViz(students, sep, depVar=target_variable, dfte="",
           header=0, verbose=1,
            lowess=False,chart_format='bokeh',max_rows_analyzed=500,max_cols_analyzed=30)
# Out:
# Shape of your Data Set loaded: (6, 6)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  2
#     Number of Integer-Categorical Columns =  0
#     Number of String-Categorical Columns =  1
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  2
#     Number of Columns to Delete =  0
#     5 Predictors classified...
#         2 variable(s) removed since they were ID or low-information variables
# ...
